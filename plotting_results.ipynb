# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
values = np.array([322.456, 360.12, 396, 399.833, 515.6275571169999])
labels = ['C++ Parallelized, I/O Queueing, Max Threads', 'C++ Parallelized, I/O Queueing, 8 Threads', 'C++ Parallelized, 8 Threads', 'C++ Serial', 'Python']

# Create bar chart
plt.bar(labels, values)

# Add labels and title
plt.xlabel('Implementation')
plt.ylabel('Runtime (seconds)')
plt.title('Tiling Implementation Runtimes')
plt.xticks(rotation=90)

# Show plot
plt.show()
